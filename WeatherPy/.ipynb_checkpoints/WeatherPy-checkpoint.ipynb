# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

#create an empty list to hold the city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
#     Parse the JSON and retrieve data
    city_weather = requests.get(city_url).json()
   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        latitude = city_weather["coord"]["lat"]
        longitude = city_weather["coord"]["lon"]
        temperature = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": latitude, 
                          "Lng": longitude, 
                          "Max Temp": temperature,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Date": date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | okhotsk
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | huadian
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 1 | sorland
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | bouca
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | ozernovskiy
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | kati
# Processing Record 28 of Set 1 | el badari
# City not found. Skipping...
# Processing Record 29 of Set 1 | pevek
# Processing Record 30 of Set 1 | gat
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | lima
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | deputatskiy
# Processing Record 36 of Set 1 | zhangjiakou
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | richards bay
# Processing Record 43 of Set 1 | araouane
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | henderson
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | mineiros
# Processing Record 49 of Set 1 | hualmay
# Processing Record 50 of Set 1 | mbeya
# Processing Record 0 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | flinders
# Processing Record 2 of Set 2 | montbrison
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | xunchang
# Processing Record 6 of Set 2 | haradok
# Processing Record 7 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | jurilovca
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | henties bay
# Processing Record 13 of Set 2 | marrakesh
# Processing Record 14 of Set 2 | juneau
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | vila
# Processing Record 17 of Set 2 | galle
# Processing Record 18 of Set 2 | cap malheureux
# Processing Record 19 of Set 2 | yulara
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | amga
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | adjumani
# Processing Record 27 of Set 2 | khasan
# Processing Record 28 of Set 2 | linxia
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | asyut
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | vestmannaeyjar
# Processing Record 34 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 2 | kinsale
# Processing Record 36 of Set 2 | broken hill
# Processing Record 37 of Set 2 | oksfjord
# Processing Record 38 of Set 2 | malm
# Processing Record 39 of Set 2 | keshan
# City not found. Skipping...
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | la rioja
# Processing Record 44 of Set 2 | savannah bight
# Processing Record 45 of Set 2 | elat
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | lucea
# Processing Record 49 of Set 2 | upernavik
# Processing Record 0 of Set 3 | hervey bay
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | severo-yeniseyskiy
# Processing Record 3 of Set 3 | laguna
# Processing Record 4 of Set 3 | auki
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | lashio
# Processing Record 7 of Set 3 | dhone
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | leningradskiy
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | lazaro cardenas
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | bone
# Processing Record 15 of Set 3 | santa maria
# Processing Record 16 of Set 3 | pahrump
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | waitati
# Processing Record 19 of Set 3 | ostrovnoy
# Processing Record 20 of Set 3 | doha
# Processing Record 21 of Set 3 | kawalu
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | vila velha
# Processing Record 27 of Set 3 | sibolga
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | kaka
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | coahuayana
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | victoria
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | am timan
# Processing Record 37 of Set 3 | wesselsbron
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | murgab
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | san policarpo
# Processing Record 43 of Set 3 | termini imerese
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | aklavik
# Processing Record 46 of Set 3 | kununurra
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | banjar
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 0 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 4 | palmer
# Processing Record 4 of Set 4 | tanout
# Processing Record 5 of Set 4 | rawson
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | leon
# Processing Record 8 of Set 4 | porto velho
# Processing Record 9 of Set 4 | luena
# Processing Record 10 of Set 4 | whitehorse
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | victor harbor
# Processing Record 15 of Set 4 | miguel hidalgo
# Processing Record 16 of Set 4 | daru
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | kristiansund
# Processing Record 19 of Set 4 | gustavo diaz ordaz
# Processing Record 20 of Set 4 | baft
# Processing Record 21 of Set 4 | mao
# Processing Record 22 of Set 4 | ilo
# Processing Record 23 of Set 4 | kleck
# City not found. Skipping...
# Processing Record 24 of Set 4 | turka
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | nuuk
# Processing Record 27 of Set 4 | takoradi
# Processing Record 28 of Set 4 | tilichiki
# Processing Record 29 of Set 4 | sitka
# Processing Record 30 of Set 4 | yar-sale
# Processing Record 31 of Set 4 | san vicente
# Processing Record 32 of Set 4 | kaltasy
# Processing Record 33 of Set 4 | brae
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | sombrerete
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | high level
# Processing Record 38 of Set 4 | burnie
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | vila franca do campo
# Processing Record 41 of Set 4 | atambua
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | ossora
# Processing Record 44 of Set 4 | qaqortoq
# Processing Record 45 of Set 4 | san jeronimo
# Processing Record 46 of Set 4 | edd
# Processing Record 47 of Set 4 | aksarka
# Processing Record 48 of Set 4 | santa fe
# Processing Record 49 of Set 4 | ostroleka
# Processing Record 0 of Set 5 | yumen
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | sao felix do xingu
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | palana
# Processing Record 5 of Set 5 | lasa
# Processing Record 6 of Set 5 | gloversville
# Processing Record 7 of Set 5 | pacific grove
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | bairiki
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | puerto del rosario
# Processing Record 12 of Set 5 | nouadhibou
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | elkton
# Processing Record 15 of Set 5 | monte aprazivel
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | praya
# Processing Record 19 of Set 5 | watsa
# Processing Record 20 of Set 5 | ambon
# Processing Record 21 of Set 5 | tynda
# Processing Record 22 of Set 5 | san cristobal
# Processing Record 23 of Set 5 | sorong
# Processing Record 24 of Set 5 | khatanga
# Processing Record 25 of Set 5 | bulgan
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | aksu
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | riachao do jacuipe
# Processing Record 30 of Set 5 | dicabisagan
# Processing Record 31 of Set 5 | wajima
# Processing Record 32 of Set 5 | adamovka
# Processing Record 33 of Set 5 | poum
# Processing Record 34 of Set 5 | batagay-alyta
# Processing Record 35 of Set 5 | rantepao
# Processing Record 36 of Set 5 | patitirion
# Processing Record 37 of Set 5 | ihosy
# Processing Record 38 of Set 5 | soe
# Processing Record 39 of Set 5 | hay river
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | quatre cocos
# Processing Record 42 of Set 5 | jumla
# Processing Record 43 of Set 5 | ahipara
# Processing Record 44 of Set 5 | tambun
# Processing Record 45 of Set 5 | gold coast
# Processing Record 46 of Set 5 | newport
# Processing Record 47 of Set 5 | sidrolandia
# Processing Record 48 of Set 5 | quesnel
# Processing Record 49 of Set 5 | talnakh
# Processing Record 0 of Set 6 | boguchany
# Processing Record 1 of Set 6 | manadhoo
# Processing Record 2 of Set 6 | shubarshi
# Processing Record 3 of Set 6 | juba
# Processing Record 4 of Set 6 | umarkot
# Processing Record 5 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 6 | gillette
# Processing Record 7 of Set 6 | paamiut
# Processing Record 8 of Set 6 | onalaska
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 6 | alofi
# Processing Record 12 of Set 6 | lata
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | aksha
# Processing Record 15 of Set 6 | grand-santi
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | alcaniz
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | nanortalik
# Processing Record 20 of Set 6 | jiexiu
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | havre-saint-pierre
# Processing Record 24 of Set 6 | rehoboth
# Processing Record 25 of Set 6 | killybegs
# Processing Record 26 of Set 6 | estelle
# Processing Record 27 of Set 6 | chuy
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | axim
# Processing Record 30 of Set 6 | raga
# Processing Record 31 of Set 6 | koshurnikovo
# Processing Record 32 of Set 6 | fairlie
# Processing Record 33 of Set 6 | toora-khem
# Processing Record 34 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | tolbazy
# Processing Record 38 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 6 | bonavista
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | wanning
# Processing Record 42 of Set 6 | nanakuli
# Processing Record 43 of Set 6 | tutoia
# Processing Record 44 of Set 6 | makakilo city
# Processing Record 45 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 6 | blythe
# Processing Record 47 of Set 6 | tecoanapa
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | szamotuly
# Processing Record 0 of Set 7 | tiarei
# Processing Record 1 of Set 7 | rockhampton
# Processing Record 2 of Set 7 | husavik
# Processing Record 3 of Set 7 | narsaq
# Processing Record 4 of Set 7 | solton
# Processing Record 5 of Set 7 | pontianak
# Processing Record 6 of Set 7 | longyan
# Processing Record 7 of Set 7 | arcachon
# Processing Record 8 of Set 7 | sfantu gheorghe
# Processing Record 9 of Set 7 | kudahuvadhoo
# Processing Record 10 of Set 7 | bonanza
# Processing Record 11 of Set 7 | zwedru
# Processing Record 12 of Set 7 | paita
# Processing Record 13 of Set 7 | shaunavon
# Processing Record 14 of Set 7 | san patricio
# Processing Record 15 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 7 | yangambi
# Processing Record 17 of Set 7 | zyryanka
# Processing Record 18 of Set 7 | pangoa
# Processing Record 19 of Set 7 | burica
# City not found. Skipping...
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | leh
# Processing Record 22 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 7 | springfield
# Processing Record 24 of Set 7 | fuling
# Processing Record 25 of Set 7 | palu
# Processing Record 26 of Set 7 | nokaneng
# Processing Record 27 of Set 7 | carnarvon
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | korla
# Processing Record 31 of Set 7 | hovd
# Processing Record 32 of Set 7 | ystad
# Processing Record 33 of Set 7 | port-cartier
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | lensk
# Processing Record 36 of Set 7 | gunjur
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | kampene
# Processing Record 39 of Set 7 | adet
# Processing Record 40 of Set 7 | ko samui
# Processing Record 41 of Set 7 | eureka
# Processing Record 42 of Set 7 | balkanabat
# Processing Record 43 of Set 7 | santa rosalia
# Processing Record 44 of Set 7 | nylstroom
# City not found. Skipping...
# Processing Record 45 of Set 7 | zlatoust
# Processing Record 46 of Set 7 | pagudpud
# Processing Record 47 of Set 7 | oranjemund
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | bandarbeyla
# Processing Record 0 of Set 8 | sindhnur
# Processing Record 1 of Set 8 | saint-paul
# Processing Record 2 of Set 8 | kahului
# Processing Record 3 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 8 | orlik
# Processing Record 5 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 8 | sabha
# Processing Record 7 of Set 8 | zhigansk
# Processing Record 8 of Set 8 | gafanha da encarnacao
# Processing Record 9 of Set 8 | valparaiso
# Processing Record 10 of Set 8 | nantucket
# Processing Record 11 of Set 8 | yagodnoye
# Processing Record 12 of Set 8 | kanalia
# Processing Record 13 of Set 8 | mnogovershinnyy
# Processing Record 14 of Set 8 | primore
# City not found. Skipping...
# Processing Record 15 of Set 8 | russell
# Processing Record 16 of Set 8 | anchorage
# Processing Record 17 of Set 8 | amapa
# Processing Record 18 of Set 8 | caravelas
# Processing Record 19 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 8 | pisco
# Processing Record 21 of Set 8 | puerto baquerizo moreno
# Processing Record 22 of Set 8 | saint-georges
# Processing Record 23 of Set 8 | grootfontein
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | antalaha
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | chapais
# Processing Record 28 of Set 8 | turayf
# Processing Record 29 of Set 8 | kenai
# Processing Record 30 of Set 8 | san andres
# Processing Record 31 of Set 8 | maningrida
# Processing Record 32 of Set 8 | provideniya
# Processing Record 33 of Set 8 | riyadh
# Processing Record 34 of Set 8 | pitimbu
# Processing Record 35 of Set 8 | pangnirtung
# Processing Record 36 of Set 8 | zhanaozen
# Processing Record 37 of Set 8 | mindelo
# Processing Record 38 of Set 8 | lavrentiya
# Processing Record 39 of Set 8 | horsham
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 8 | hurghada
# Processing Record 42 of Set 8 | vostok
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | te anau
# Processing Record 45 of Set 8 | goma
# Processing Record 46 of Set 8 | hobyo
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | kavaratti
# Processing Record 49 of Set 8 | ankazoabo
# Processing Record 0 of Set 9 | evanston
# Processing Record 1 of Set 9 | tarsus
# Processing Record 2 of Set 9 | makokou
# Processing Record 3 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 9 | yoichi
# Processing Record 5 of Set 9 | barra patuca
# Processing Record 6 of Set 9 | esperance
# Processing Record 7 of Set 9 | moose factory
# Processing Record 8 of Set 9 | ixtapa
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | biak
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | baneh
# Processing Record 13 of Set 9 | labuan
# Processing Record 14 of Set 9 | mountain home
# Processing Record 15 of Set 9 | kryvyy rih
# Processing Record 16 of Set 9 | florissant
# Processing Record 17 of Set 9 | bilma
# Processing Record 18 of Set 9 | gorin
# Processing Record 19 of Set 9 | nishihara
# Processing Record 20 of Set 9 | atar
# Processing Record 21 of Set 9 | saint-augustin
# Processing Record 22 of Set 9 | quang ngai
# Processing Record 23 of Set 9 | uglovskoye
# Processing Record 24 of Set 9 | semey
# Processing Record 25 of Set 9 | manbij
# Processing Record 26 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 9 | matay
# Processing Record 28 of Set 9 | aguie
# Processing Record 29 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 9 | port hawkesbury
# Processing Record 31 of Set 9 | great bend
# Processing Record 32 of Set 9 | ribeira grande
# Processing Record 33 of Set 9 | pak phanang
# Processing Record 34 of Set 9 | puerto narino
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | birjand
# Processing Record 37 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 38 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | vadso
# Processing Record 40 of Set 9 | deder
# Processing Record 41 of Set 9 | katangli
# Processing Record 42 of Set 9 | salinas
# Processing Record 43 of Set 9 | chihuahua
# Processing Record 44 of Set 9 | likasi
# Processing Record 45 of Set 9 | thap than
# Processing Record 46 of Set 9 | buala
# Processing Record 47 of Set 9 | akdepe
# Processing Record 48 of Set 9 | iranshahr
# Processing Record 49 of Set 9 | palimbang
# Processing Record 0 of Set 10 | maua
# Processing Record 1 of Set 10 | santa rosa
# Processing Record 2 of Set 10 | tahoua
# Processing Record 3 of Set 10 | carballo
# Processing Record 4 of Set 10 | waipawa
# Processing Record 5 of Set 10 | gardez
# Processing Record 6 of Set 10 | muli
# Processing Record 7 of Set 10 | gander
# Processing Record 8 of Set 10 | sao filipe
# Processing Record 9 of Set 10 | urucara
# Processing Record 10 of Set 10 | manjacaze
# Processing Record 11 of Set 10 | boende
# Processing Record 12 of Set 10 | severnoye
# Processing Record 13 of Set 10 | tezu
# Processing Record 14 of Set 10 | tahe
# Processing Record 15 of Set 10 | cascais
# Processing Record 16 of Set 10 | ritchie
# Processing Record 17 of Set 10 | ryotsu
# Processing Record 18 of Set 10 | minna
# Processing Record 19 of Set 10 | paralimni
# Processing Record 20 of Set 10 | puerto penasco
# Processing Record 21 of Set 10 | umm lajj
# Processing Record 22 of Set 10 | tambacounda
# Processing Record 23 of Set 10 | mezen
# Processing Record 24 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 10 | zmievka
# City not found. Skipping...
# Processing Record 29 of Set 10 | komatsushima
# Processing Record 30 of Set 10 | la ronge
# Processing Record 31 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 10 | zhangye
# Processing Record 33 of Set 10 | samarai
# Processing Record 34 of Set 10 | solnechnyy
# Processing Record 35 of Set 10 | abu samrah
# Processing Record 36 of Set 10 | bella union
# Processing Record 37 of Set 10 | lukovetskiy
# Processing Record 38 of Set 10 | semme
# Processing Record 39 of Set 10 | sapa
# Processing Record 40 of Set 10 | buraydah
# Processing Record 41 of Set 10 | weligama
# Processing Record 42 of Set 10 | maceio
# Processing Record 43 of Set 10 | marsh harbour
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | xaxim
# Processing Record 46 of Set 10 | hailun
# Processing Record 47 of Set 10 | the pas
# Processing Record 48 of Set 10 | laiyang
# Processing Record 49 of Set 10 | jiuquan
# Processing Record 0 of Set 11 | posadas
# Processing Record 1 of Set 11 | podgornoye
# Processing Record 2 of Set 11 | kirsanov
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | fez
# Processing Record 5 of Set 11 | nanning
# Processing Record 6 of Set 11 | mae sai
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | beckley
# Processing Record 9 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 11 | gurupi
# Processing Record 11 of Set 11 | amlame
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | vagur
# Processing Record 14 of Set 11 | jinchang
# Processing Record 15 of Set 11 | prince rupert
# Processing Record 16 of Set 11 | naze
# Processing Record 17 of Set 11 | calvinia
# Processing Record 18 of Set 11 | douglas
# Processing Record 19 of Set 11 | balabac
# Processing Record 20 of Set 11 | bhandaria
# Processing Record 21 of Set 11 | kirkwall
# Processing Record 22 of Set 11 | sur
# Processing Record 23 of Set 11 | porto nacional
# Processing Record 24 of Set 11 | galesong
# Processing Record 25 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 11 | chernogorsk
# Processing Record 27 of Set 11 | terney
# Processing Record 28 of Set 11 | mitu
# Processing Record 29 of Set 11 | jaguey grande
# Processing Record 30 of Set 11 | staunton
# Processing Record 31 of Set 11 | zapolyarnyy
# Processing Record 32 of Set 11 | tres lagoas
# Processing Record 33 of Set 11 | cidreira
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | port-gentil
# Processing Record 36 of Set 11 | kodinsk
# Processing Record 37 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 11 | sembe
# Processing Record 39 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 11 | drexel heights
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | sarakhs
# Processing Record 43 of Set 11 | catuday
# Processing Record 44 of Set 11 | corinth
# Processing Record 45 of Set 11 | penicuik
# Processing Record 46 of Set 11 | dasoguz
# Processing Record 47 of Set 11 | veraval
# Processing Record 48 of Set 11 | port shepstone
# Processing Record 49 of Set 11 | shirokiy
# Processing Record 0 of Set 12 | broome
# Processing Record 1 of Set 12 | rio grande
# Processing Record 2 of Set 12 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 3 of Set 12 | pilar
# Processing Record 4 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 12 | sola
# Processing Record 6 of Set 12 | nalut
# Processing Record 7 of Set 12 | port blair
# Processing Record 8 of Set 12 | piney green
# Processing Record 9 of Set 12 | serenje
# Processing Record 10 of Set 12 | taylorville
# Processing Record 11 of Set 12 | taos
# Processing Record 12 of Set 12 | ucluelet
# Processing Record 13 of Set 12 | kitui
# Processing Record 14 of Set 12 | walvis bay
# Processing Record 15 of Set 12 | portree
# Processing Record 16 of Set 12 | san juan
# Processing Record 17 of Set 12 | warrnambool
# Processing Record 18 of Set 12 | tsentralnyy
# City not found. Skipping...
# Processing Record 19 of Set 12 | muros
# Processing Record 20 of Set 12 | chicama
# Processing Record 21 of Set 12 | piacabucu
# Processing Record 22 of Set 12 | sortova
# Processing Record 23 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 12 | chumikan
# Processing Record 25 of Set 12 | darnah
# Processing Record 26 of Set 12 | opole lubelskie
# Processing Record 27 of Set 12 | parkes
# Processing Record 28 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 29 of Set 12 | imbituba
# Processing Record 30 of Set 12 | port hedland
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | mujiayingzi
# Processing Record 33 of Set 12 | dekar
# Processing Record 34 of Set 12 | rio gallegos
# Processing Record 35 of Set 12 | mount isa
# Processing Record 36 of Set 12 | pathein
# Processing Record 37 of Set 12 | namie
# Processing Record 38 of Set 12 | buribay
# Processing Record 39 of Set 12 | sal rei
# Processing Record 40 of Set 12 | holme
# Processing Record 41 of Set 12 | fort collins
# Processing Record 42 of Set 12 | orel
# Processing Record 43 of Set 12 | amarante
# Processing Record 44 of Set 12 | tessalit
# Processing Record 45 of Set 12 | nieuw amsterdam
# Processing Record 46 of Set 12 | kingsland
# Processing Record 47 of Set 12 | bayonet point
# Processing Record 48 of Set 12 | ladan
# Processing Record 49 of Set 12 | san ignacio
# Processing Record 0 of Set 13 | king city
# Processing Record 1 of Set 13 | harper
# Processing Record 2 of Set 13 | botou
# Processing Record 3 of Set 13 | ulladulla
# Processing Record 4 of Set 13 | kalulushi
# Processing Record 5 of Set 13 | oktyabrskiy
# Processing Record 6 of Set 13 | floro
# Processing Record 7 of Set 13 | pilot butte
# Processing Record 8 of Set 13 | mayo
# Processing Record 9 of Set 13 | buenaventura
# Processing Record 10 of Set 13 | zelenoborsk
# Processing Record 11 of Set 13 | teya
# Processing Record 12 of Set 13 | athabasca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     78.55        91          53
# 1    Georgetown   5.4112  100.3354     89.55        70          40
# 2        Faanui -16.4833 -151.7500     77.67        64           3
# 3       Okhotsk  59.3833  143.3000     56.66        54         100
# 4        Atuona  -9.8000 -139.0333     80.49        77          98
#
#    Wind Speed Country        Date
# 0        5.01      EC  1685588377
# 1        4.61      MY  1685588362
# 2       16.04      PF  1685588406
# 3       15.39      RU  1685588376
# 4       11.05      PF  1685588376

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     78.55        91          53
# 1    Georgetown   5.4112  100.3354     89.55        70          40
# 2        Faanui -16.4833 -151.7500     77.67        64           3
# 3       Okhotsk  59.3833  143.3000     56.66        54         100
# 4        Atuona  -9.8000 -139.0333     80.49        77          98
#
#    Wind Speed Country        Date
# 0        5.01      EC  1685588377
# 1        4.61      MY  1685588362
# 2       16.04      PF  1685588406
# 3       15.39      RU  1685588376
# 4       11.05      PF  1685588376

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        Puerto Ayora  -0.7393  -90.3518     78.55        91          53
# 1          Georgetown   5.4112  100.3354     89.55        70          40
# 2              Faanui -16.4833 -151.7500     77.67        64           3
# 3             Okhotsk  59.3833  143.3000     56.66        54         100
# 4              Atuona  -9.8000 -139.0333     80.49        77          98
# ...               ...      ...       ...       ...       ...         ...
# 554              Mayo  38.8876  -76.5119     66.97        86           0
# 555      Buenaventura   3.8801  -77.0312     75.96        94         100
# 556       Zelenoborsk  61.4669   64.0333     68.38        62         100
# 557              Teya  60.3778   92.6267     74.08        26          87
# 558         Athabasca  54.7169 -113.2854     57.96        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.01      EC  1685588377
# 1              4.61      MY  1685588362
# 2             16.04      PF  1685588406
# 3             15.39      RU  1685588376
# 4             11.05      PF  1685588376
# ...             ...     ...         ...
# 554            4.61      US  1685588740
# 555            2.64      CO  1685589042
# 556           12.15      RU  1685589042
# 557            5.59      RU  1685588459
# 558            5.44      CA  1685589043
#
# [559 rows x 9 columns]

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties 
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature(F)')
plt.title('City Latitude vs. Max Temperature')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')
plt.scatter(x_values,y_values,marker='o', facecolor = 'blue', edgecolor='black', alpha=0.5)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values):
    # Perform linear regression
    (slope,intercept,rvalue,pvalue,stderr) = linregress(x_values,y_values)

    # Create scatter plot
    plt.scatter(x_values, y_values, marker='o', color='blue', alpha=0.5, label='Data Points')

    # Create regression line
    regression_line = slope * x_values + intercept
    plt.plot(x_values, regression_line, color='red', label='Regression Line')

    # Determine the appropriate coordinates for annotation
    # Add 5% to the maximum x-value
    x_annotate = x_values.max() + (x_values.max() - x_values.min()) * 0.05  
    # Add 5% to the maximum y-value
    y_annotate = regression_line.max() + (regression_line.max() - regression_line.min()) * 0.05  

# Annotate the line equation
    line_eq = f'y = {str(round(slope, 2))}x + {str(round(intercept, 2))}'
    plt.annotate(line_eq, (x_annotate, y_annotate), fontsize=15, color='r')
    print(f'The r-value is: {rvalue}')
    
    # Display legend
    plt.legend()

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        Georgetown   5.4112  100.3354     89.55        70          40
# 3           Okhotsk  59.3833  143.3000     56.66        54         100
# 5           Huadian  42.9633  126.7478     77.85        37           0
# 6           Sorland  67.6670   12.6934     40.86        56          93
# 8        Nikolskoye  59.7035   30.7861     50.81        70          95
#
#          Wind Speed Country        Date
# City_ID
# 1              4.61      MY  1685588362
# 3             15.39      RU  1685588376
# 5             14.74      CN  1685588931
# 6             20.69      NO  1685588455
# 8              2.91      RU  1685588383

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        Puerto Ayora  -0.7393  -90.3518     78.55        91          53
# 2              Faanui -16.4833 -151.7500     77.67        64           3
# 4              Atuona  -9.8000 -139.0333     80.49        77          98
# 7               Vaini -21.2000 -175.2000     77.16        88          75
# 9        Kruisfontein -34.0033   24.7314     52.41        74           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.01      EC  1685588377
# 2             16.04      PF  1685588406
# 4             11.05      PF  1685588376
# 7             11.50      TO  1685588372
# 9              5.99      ZA  1685588442

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature(F)')
plt.title('Northern Hemisphere Latitude vs. Max. Temperature')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: -0.7844969690237137

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature(F)')
plt.title('Southern Hemisphere Latitude vs. Max. Temperature')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.695573811576806

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and max temperature is clear. As the latitude in the northern hemisphere increases, the temperature decreases. We see the opposite for the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Latitude vs. Humidity')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.00033617746710032885

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Latitude vs. Humidity')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.059885295930390985

# %% [markdown]
# **Discussion about the linear relationship:** There is slight correlation between latitude and humidity in the northern and southern hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Latitude vs. Cloudiness')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.03121380835959468

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere Latitude vs. Cloudiness')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.044405797382774455

# %% [markdown]
# **Discussion about the linear relationship:** There is a slight positive correlation between the latitude and the cloudiness of cities in the northern and southern hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere Latitude vs. Wind Speed')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: 0.112052355872154

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Set labels and title
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere Latitude vs. Wind Speed')

create_linear_regression_plot(x_values, y_values)
# Out:
# The r-value is: -0.1838555167090535

# %% [markdown]
# **Discussion about the linear relationship:** There seems to be little to no correlation between the latitude and wind speed of cities in the northern hemisphere. There is a slight negative correlation between these same two factors for the cities in the southen hemisphere.
